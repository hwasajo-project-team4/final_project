# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm
import random
import os

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

DATA_PATH = "/content/drive/MyDrive/Colab Notebooks/data/"
SEED = 42

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.32.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 50.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.32.1

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
skincare = pd.read_csv(f"{DATA_PATH}아모레크롤링_스킨케어.csv")

# %%
skincare = skincare.drop(columns=['상품분류'])

# %%
makeup = pd.read_csv(f"{DATA_PATH}메이크업 별점.csv")

# %%
food = pd.read_csv(f"{DATA_PATH}뷰티푸드 별점.csv")

# %%
perfume = pd.read_csv(f"{DATA_PATH}향수 별점.csv")

# %%
thing = pd.read_csv(f"{DATA_PATH}소품도구 별점.csv")

# %%
thing
# Out:
#       브랜드명                   상품명        사용자 이름  별점      리뷰작성날짜      나이  성별  \
# 0       헤라  블랙 쿠션 제로-비티 핏 퍼프 2EA       ogy4***   2  2021.10.29     20대  여성
# 1       헤라  블랙 쿠션 제로-비티 핏 퍼프 2EA        bjhd**   5  2022.02.17     30대  남성
# 2       헤라  블랙 쿠션 제로-비티 핏 퍼프 2EA     kitt*****   5  2022.07.19     20대  여성
# 3       헤라  블랙 쿠션 제로-비티 핏 퍼프 2EA      sjji****   5  2021.08.14  50대 이상  여성
# 4       헤라  블랙 쿠션 제로-비티 핏 퍼프 2EA  wlsg********   5  2022.07.20     30대  여성
# ...    ...                   ...           ...  ..         ...     ...  ..
# 18603  피카소        [피카소] 103A 파우더          suy*   5  2019.08.07     20대  여성
# 18604  피카소        [피카소] 103A 파우더      yyou****   5  2019.06.25     20대  여성
# 18605  피카소        [피카소] 103A 파우더      amil****   5  2019.05.18     40대  여성
# 18606  피카소        [피카소] 103A 파우더     vbgu*****   4  2019.04.30     30대  여성
# 18607  피카소        [피카소] 103A 파우더         sony*   5  2019.03.15  50대 이상  남성
#
#       피부타입 피부트러블                                                 리뷰
# 0      NaN   NaN  -디자인\n\n*5점 만점 기준*\n\n-디자인\n: 퍼프 위의 가죽 느낌으로 고급...
# 1      NaN   NaN  좋아요! 최고에요!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!...
# 2      NaN   NaN  퍼프는 빨아서 사용하는 것도 찝찝하고 블랙쿠션에는 블랙쿠션 퍼프가 딱이라고 생각해서...
# 3      NaN   NaN  퍼프가 발림성이 정말로 쫀쫀해요 쫀쫀 !\n두 개의 퍼프가 비닐과 pvc백에 이중 ...
# 4      NaN   NaN  밀착력에 짱 ! 뭉침없이 발라지는 퍼프, 저는 위생상 2주일에 한번씩 직접 퍼프를 ...
# ...    ...   ...                                                ...
# 18603  NaN   NaN                 명불허전이에요~\n파우더나 블러셔 용도로 매우 잘쓰고 있어요!
# 18604  NaN   NaN  부드럽고 파우더 바르기 좋아요!\n다른 브러쉬로 바르면 파우더가 조금 떠서 피카소 ...
# 18605  NaN   NaN  피카소브러쉬 너무좋아요 계속사게되요 모질도 너무 부드럽고 ~ \n이번에 행사해서 할...
# 18606  NaN   NaN  가격은 좀 비싸지만 생각보다 괜찮은것 같아요\n배송은 하루만에 받았구요 보호케이스가...
# 18607  NaN   NaN                        피카소브러쉬가 좋다고 해서 세일에 구매해서 좋아요
#
# [18608 rows x 10 columns]

# %%
frames = [skincare, makeup, food, perfume, thing]
df = pd.concat(frames, ignore_index=True)
df
# Out:
#          브랜드명                    상품명       사용자 이름  별점      리뷰작성날짜      나이  성별  \
# 0       이니스프리  화산송이 모공 바하 클렌징 폼 150g  0103*******   5  2022.09.27     40대  여성
# 1       이니스프리  화산송이 모공 바하 클렌징 폼 150g      lsm2***   5  2022.08.15     40대  여성
# 2       이니스프리  화산송이 모공 바하 클렌징 폼 150g      gpdl***   5  2022.12.24     20대  여성
# 3       이니스프리  화산송이 모공 바하 클렌징 폼 150g      zoll***   5  2022.09.30     30대  여성
# 4       이니스프리  화산송이 모공 바하 클렌징 폼 150g     snow****   5  2022.09.30  50대 이상  여성
# ...       ...                    ...          ...  ..         ...     ...  ..
# 220177    피카소         [피카소] 103A 파우더         suy*   5  2019.08.07     20대  여성
# 220178    피카소         [피카소] 103A 파우더     yyou****   5  2019.06.25     20대  여성
# 220179    피카소         [피카소] 103A 파우더     amil****   5  2019.05.18     40대  여성
# 220180    피카소         [피카소] 103A 파우더    vbgu*****   4  2019.04.30     30대  여성
# 220181    피카소         [피카소] 103A 파우더        sony*   5  2019.03.15  50대 이상  남성
#
#        피부타입 피부트러블                                                 리뷰
# 0        지성    모공  남편이 극지성이에요. 원래 수퍼화산송이 미셀라만 꾸준히 사용해 오다가 지성 전용이라...
# 1        건성   건조함  여름이라 집에 와서 메이크업 클렌징 해줄때 꼭 이중세안 해주는데 이 폼 클렌징으로 ...
# 2       복합성   트러블  이니스프리 폼클렌징은 피부에 자극적이지 않아 좋아요 선크림만 사용해도 꼭 폼까지 써...
# 3        건성   건조함  저희 엄마가 이 제품이 클렌징이 제일 잘된다고 좋아하서 1+1 이벤트하길래 4개 쟁...
# 4        지성    모공  여름이라서 모공이 넓어지는것 같아서 구매해서 사용해보니 촉촉하고 피부땡기지 않아서 ...
# ...     ...   ...                                                ...
# 220177  NaN   NaN                 명불허전이에요~\n파우더나 블러셔 용도로 매우 잘쓰고 있어요!
# 220178  NaN   NaN  부드럽고 파우더 바르기 좋아요!\n다른 브러쉬로 바르면 파우더가 조금 떠서 피카소 ...
# 220179  NaN   NaN  피카소브러쉬 너무좋아요 계속사게되요 모질도 너무 부드럽고 ~ \n이번에 행사해서 할...
# 220180  NaN   NaN  가격은 좀 비싸지만 생각보다 괜찮은것 같아요\n배송은 하루만에 받았구요 보호케이스가...
# 220181  NaN   NaN                        피카소브러쉬가 좋다고 해서 세일에 구매해서 좋아요
#
# [220182 rows x 10 columns]

# %%
def chatbot(df):
    model_name = "noahkim/KoT5_news_summarization"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    while True:
        title = input("상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): ")
        if title.lower() in ['q', 'quit']:
            print("챗봇을 종료합니다.")
            break
        # 여러 키워드에 대한 처리
        keywords = title.split()
        condition = lambda x: all(keyword.lower() in x.lower() for keyword in keywords)
        # 중복 제거를 위해 unique() 사용
        matching_titles = [t for t in df['상품명'].unique().tolist() if condition(t)]
        if not matching_titles:
            print("해당 상품이 없습니다.")
            continue
        print("일치하는 상품명 목록:")
        for idx, matching_title in enumerate(matching_titles, start=1):
            print(f"{idx}. {matching_title}")
        # 사용자가 상품을 선택하도록 함
        selected_idx = int(input("상품을 선택하세요 (번호 입력): "))
        selected_title = matching_titles[selected_idx - 1]
        # 선택한 상품의 리뷰 가져오기
        reviews = df[df['상품명'] == selected_title]['리뷰'].to_list()
        reviews_text = ' '.join(reviews)
        # 리뷰 요약
        inputs = tokenizer(reviews_text, return_tensors="pt", max_length=1024, truncation=True)
        summary_ids = model.generate(inputs["input_ids"], num_beams=4, min_length=40, max_length=200, early_stopping=True)
        summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
        print(f"{selected_title}의 전체 리뷰 요약: {summary}")

# %%
chatbot(df)
# Out:
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): 화산송이 클렌징
# 해당 상품이 없습니다.
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): 화산송이
# 일치하는 상품명 목록:
# 1. 화산송이 모공 바하 클렌징 폼 150g
# 2. 수퍼 화산송이 모공 마스크 100ml
# 3. 화산송이 모공 바하 클렌징폼  250g
# 상품을 선택하세요 (번호 입력): 1
# 화산송이 모공 바하 클렌징 폼 150g의 전체 리뷰 요약: 여름이라 집에 와서 메이크업 클렌징 해줄때 꼭 이중세안 해주는데 이 폼 클렌징으로 세안 해주면 좋은점이 뾰루지가 안나고 뽀드득하게 씻겨줘서 좋고 피지과도할때 딥 클렌징폼이라 그런지 피부에 자극이 없는건 아니지만 격일로 쓰기에 좋은거같아요.
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): 블랙 쿠션
# 일치하는 상품명 목록:
# 1. 블랙 쿠션 SPF34/PA++ (본품15g+리필15g)
# 2. [리필] 블랙 쿠션 SPF34/PA++ 15g
# 3. 헤라X39ETC 엑스커베이션 블랙 쿠션 21N1 15g x 2
# 4. 블랙 쿠션 제로-비티 핏 퍼프 2EA
# 상품을 선택하세요 (번호 입력): 1
# 블랙 쿠션 SPF34/PA++ (본품15g+리필15g)의 전체 리뷰 요약: 블랙쿠션이 초창기 나왔을 때도 시큰둥했고 수많은 브랜드에서 온갖 쿠션을 써봤는데 단 한번도 리필을 갈아끼워 본 적이 없었는데 헤라 블랙쿠션은 그 귀차니즘을 뚫고 마구마구 추천하고픈 제품이라 고민하시는 분들께 도움되고자 몇 자 적어봅니다.
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): 피카소
# 일치하는 상품명 목록:
# 1. [피카소X함경식] 메이크업 스파츌라+미니 믹싱 팔레트 기획세트
# 2. [피카소] 아이래쉬 컬러 실버 + 실리콘 리필 패드 2EA
# 3. [피카소] 라텍스 스퀘어 스펀지 20P(케이스포함)(+스퀘어 스펀지 케이스 증정)
# 4. [피카소] 파우더 퍼프 세트(5개입)
# 5. [피카소X함경식] 메이크업 스파츌라+스펀지 2P 기획세트
# 6. [피카소] 눈썹칼
# 7. [피카소꼴레지오니] 501 립
# 8. [피카소] 캐리어 콤보 파우치
# 9. [피카소] Voyage 56043 포터블 립브러쉬
# 10. [피카소X함경식] 메이크업 스파츌라
# 11. [피카소] 159 파우더
# 12. [피카소꼴레지오니] 레더 원통 브러쉬 케이스
# 13. [피카소꼴레지오니] 19 아이섀도우
# 14. [피카소] 401FLAT 컨실러
# 15. [피카소] 719 comb 아이브로우
# 16. [피카소] 생기창조 108 블러셔
# 17. [피카소] 투웨이 메이크업 스파츌라(+복조리 파우치 증정)
# 18. [피카소] 커브드 메이크업 스파츌라(+복조리 파우치 증정)
# 19. [피카소] 메이크업 브러쉬 홀더(브러쉬 건조대)
# 20. [피카소] 멀티 캐리어 파우치 웜그레이
# 21. [피카소] 메이크업 브러쉬 클렌징 패드 60매
# 22. [피카소꼴레지오니] 데일리 메이크업 파우치
# 23. [피카소] 스펀지 케이스
# 24. [피카소] 270 컨실러
# 25. [피카소꼴레지오니x차니베어] 하트 손거울
# 26. [피카소꼴레지오니x차니베어] 복조리 파우치
# 27. [피카소] 아이섀도우 브러쉬 미니 3종 세트 (+클렌저 미니 증정)
# 28. [피카소꼴레지오니] 라운드 팁 트위저
# 29. [피카소꼴레지오니] 컬러 스펀지 퍼프 세트(17개입)
# 30. [피카소] 메이크업 브러쉬 클렌저 50ml
# 31. [피카소꼴레지오니] 20 듀얼 아이브로우
# 32. [피카소꼴레지오니] 502 블렌딩
# 33. [피카소꼴레지오니] 160 팬 블러셔
# 34. [피카소] 132 파운데이션
# 35. [피카소] 속눈썹 빗
# 36. [피카소] 103A 파우더 + 102 핑거 파우더
# 37. [피카소] 메이크업 브러쉬 클렌저 200ml(+펌핑기 증정)
# 38. [피카소꼴레지오니] 브러쉬 클렌징 매트
# 39. [피카소] 속눈썹 풀(쌍커풀액)
# 40. [피카소] 윤기창조 FB17 + 에어퍼프 프리미엄 프로
# 41. [피카소] 301 아이브로우
# 42. [피카소꼴레지오니] 240 아이섀도우
# 43. [피카소꼴레지오니] 브러쉬 커버
# 44. [피카소꼴레지오니] 컬러팁 스펀지
# 45. [피카소] 아이미 속눈썹 10개 세트 (10종 택1)
# 46. [피카소꼴레지오니] 아이블렌딩 세트 (19+239)
# 47. [피카소꼴레지오니] 미니 믹싱팔레트&거울
# 48. [피카소] 라텍스 스퀘어 메이크업 스펀지 6p(+스퀘어 스펀지 케이스 증정)
# 49. [피카소꼴레지오니] 필수 아이메이크업 세트 (207A+301)
# 50. [피카소꼴레지오니] 컨투어링 아이 세트 (224+302)
# 51. [피카소꼴레지오니] FB17 파운데이션
# 52. [피카소꼴레지오니] 777 아이섀도우
# 53. [피카소꼴레지오니] 305 아이라이너
# 54. [피카소꼴레지오니] 302 아이섀도우
# 55. [피카소꼴레지오니] 301 아이브로우
# 56. [피카소꼴레지오니] 239 아이섀도우
# 57. [피카소꼴레지오니] 224 아이섀도우
# 58. [피카소꼴레지오니] 221 아이섀도우
# 59. [피카소꼴레지오니] 207A 아이섀도우
# 60. [피카소꼴레지오니] 131 파운데이션
# 61. [피카소꼴레지오니] 108 블러셔
# 62. [피카소꼴레지오니] 103A 파우더
# 63. [피카소] 아이미 속눈썹 포인트 30호
# 64. [피카소] 에어퍼프 프리미엄 프로 3개 세트
# 65. [피카소] 에어퍼프 프리미엄 프로
# 66. [피카소] 310 컨실러
# 67. [피카소] 402 스크류 브러쉬
# 68. [피카소] 409 아이라이너
# 69. [피카소] 501 립
# 70. [피카소] 505 립
# 71. [피카소] 602 쉐이딩
# 72. [피카소] 712 컨실러
# 73. [피카소] 718 아이브로우
# 74. [피카소] 721 쉐이딩
# 75. [피카소] 722 사선 아이섀도우
# 76. [피카소] 722 일자 아이섀도우
# 77. [피카소] 723 팬 파우더
# 78. [피카소] 725 쉐이딩_헤어라인
# 79. [피카소] 747 아이섀도우
# 80. [피카소] 777 아이섀도우
# 81. [피카소] 멀티퍼펙트 컨투어 01
# 82. [피카소] 윤기창조 FB17 파운데이션
# 83. [피카소] PONY14 블러셔
# 84. [피카소] PROOF SILVER 14 컨실러
# 85. [피카소] 239 아이섀도우
# 86. [피카소] PROOF SILVER 08 컨실러
# 87. [피카소] 224 아이섀도우
# 88. [피카소] 219 SQ 아이섀도우
# 89. [피카소] 219 아이섀도우
# 90. [피카소] 217 아이섀도우
# 91. [피카소] 207A 아이섀도우
# 92. [피카소] 207 아이섀도우
# 93. [피카소] 206A 아이섀도우
# 94. [피카소] 204 아이섀도우
# 95. [피카소] 라텍스 원형 메이크업 스펀지 6p(+스퀘어 스펀지 케이스 증정)
# 96. [피카소] 촉촉 에어퍼프
# 97. [피카소] 샤프너
# 98. [피카소] 아이래쉬 컬러 실리콘 리필 패드 4ea
# 99. [피카소] 아이래쉬 컬러 블랙 + 실리콘 리필 패드 2ea
# 100. [피카소] 휴그레이 트위져(케이스증정)
# 101. [피카소] 브러쉬커버
# 102. [피카소] 블랙 메이크업 스펀지
# 103. [피카소] 194 컨실러
# 104. [피카소] 133 픽싱 파우더
# 105. [피카소] 극한의 모공브러쉬 131 파운데이션
# 106. [피카소] 130 파운데이션
# 107. [피카소] 103A 파우더
# 상품을 선택하세요 (번호 입력): 5
# [피카소X함경식] 메이크업 스파츌라+스펀지 2P 기획세트의 전체 리뷰 요약: 유튜브에서 화장을 편리하게하고 밀착력을 높일 수 있는 제품으로 스파츌라를 보고 구매를 했는데 사용법을 익히는 중이라 열심히 해보려고 합니다.
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): 컨실러
# 일치하는 상품명 목록:
# 1. 블랙 컨실러 스프레드 커버 5g
# 2. 테이핑컨실러롱웨어
# 3. [피카소] 401FLAT 컨실러
# 4. [피카소] 270 컨실러
# 5. 231 풀커버리지 컨실러
# 6. [피카소] 310 컨실러
# 7. [피카소] 712 컨실러
# 8. [피카소] PROOF SILVER 14 컨실러
# 9. [피카소] PROOF SILVER 08 컨실러
# 10. [피카소] 194 컨실러
# 상품을 선택하세요 (번호 입력): 5
# 231 풀커버리지 컨실러의 전체 리뷰 요약: 파데브러시는 더툴랩 컨실러 브러시로 정착했는데 이 라지사이즈가 기존 버전의 살짝 아쉬웠던 크기 단점을 보완해 나와 완벽한 것 같아 정착할지는 좀더 써봐야 알것같지만 현재로써는 만족스럽다.
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): q
# 챗봇을 종료합니다.

# %%
import re

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 15.2 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
def keyword(title):
  texts = df[df['상품명'] == title]['리뷰'].to_list()
  okt = Okt()
  nouns_list = []
  for text in texts:
    nouns = okt.nouns(text)
    nouns_list.extend(nouns)

  count = Counter(nouns_list)

  # 명사 빈도 카운트
  noun_list = count.most_common(100)
  for v in noun_list:
    if any(keyword in v[0] for keyword in ['지성', '건성', '복합성','여드름','탄력','모공','민감성','봄웜','웜톤','봄웜톤','봄라이트','봄라','봄브라이트','여쿨','여라','여름라이트','여름뮤트','여뮽','뮤트','가을웜톤','가을뮤트','갈딥','가을딥','갈웜','겨쿨','겨울브라이트','쿨톤']):
      print("이 제품은 "+v[0]+"의 피부를 가진 분들에게 추천드립니다.")

# %%
keyword('화산송이 모공 바하 클렌징 폼 150g')
# Out:
# 이 제품은 모공의 피부를 가진 분들에게 추천드립니다.
# 이 제품은 여드름의 피부를 가진 분들에게 추천드립니다.
# 이 제품은 건성의 피부를 가진 분들에게 추천드립니다.

# %%
def keyword_bot(df):
  while True:
    title = input("상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): ")
    if title.lower() in ['q','quit']:
      print("챗봇을 종료합니다.")
      break
    matching_titles = df[df['상품명'].str.contains(title, case=False)]['상품명'].unique().tolist()
    if not matching_titles:
      print("해당 상품이 없습니다.")
      continue
    print("일치하는 상품명 목록:")
    for idx, matching_title in enumerate(matching_titles, start=1):
      print(f"{idx}. {matching_title}")
    selected_idx = int(input("상품을 선택하세요 (번호 입력): "))
    selected_title = matching_titles[selected_idx - 1]
    #리뷰 가져오기
    reviews = df[df['상품명'] == selected_title]['리뷰'].to_list()
    reviews_text = ' '.join(reviews)
    #키워드 추출
    okt = Okt()
    nouns_list = []
    for review in reviews_text:
      nouns = okt.nouns(review)
      nouns_list.extend(nouns)

    count = Counter(nouns_list)

    # 명사 빈도 카운트
    noun_list = count.most_common(500)
    for n in noun_list:
      if any(keyword in n[0] for keyword in ['지성', '건성', '피지','복합성','여드름','트러블','탄력','모공','민감성','주름','진정','보습','봄웜','웜톤','봄웜톤','봄라이트','봄라','봄브라이트','여쿨','여라','여름라이트','여름뮤트','여뮽','뮤트','가을웜톤','가을뮤트','갈딥','가을딥','갈웜','겨쿨','겨울브라이트','쿨톤']):
        print("이 제품은 "+n[0]+"인 분들에게 추천합니다.")

# %%
keyword_bot(df)
# Out:
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): 화산송이
# 일치하는 상품명 목록:
# 1. 화산송이 모공 바하 클렌징 폼 150g
# 2. 수퍼 화산송이 모공 마스크 100ml
# 3. 화산송이 모공 바하 클렌징폼  250g
# 상품을 선택하세요 (번호 입력): 1
# 상품명을 입력하세요 (종료하려면 'q' 또는 'quit' 입력): q
# 챗봇을 종료합니다.
